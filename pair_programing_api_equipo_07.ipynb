# %% [markdown]
# 1. Extracción de Datos a Nivel Nacional:
#
# Extraer datos de generación de energía renovable y no renovable a nivel nacional desde el 1 de enero de 2011 hasta el 31 de diciembre de 2022. La información debe ser recopilada a nivel mensual.
#
# Transformar los datos para incluir una columna nueva que identifique si la energía es renovable o no renovable.
#
# Almacenar los datos en un DataFrame

# %%
import pandas as pd
import requests
import re
pd.set_option('display.max_columns', None)

# %%
def llamada_api(url):
    llamada=requests.get('https://www.ree.es/es/apidatos/datos/generacion/evolucion-renovable-no-renovable')
    print(f'respuesta a llamada:{llamada.status_code}')
    if llamada.status_code !=200:
        print(f'motivo de fallo:{llamada.reason}')
        print(llamada.text)
        
    else:
        return llamada.json()
    
    
    #GET /https://www.ree.es/es/apidatos/datos/generacion/evolucion-renovable-no-renovable

# %%
url_red_electrica= 'https://www.ree.es/es/apidatos'
respuesta_red= llamada_api(url_red_electrica)
print(f'respuesta:{respuesta_red}')
# Out:
# respuesta a llamada:404
# motivo de fallo:Not Found
#
#
# <!-- THEME DEBUG -->
# <!-- THEME HOOK: 'html' -->
# <!-- FILE NAME SUGGESTIONS:
#    * html--apidatos--datos--generacion--evolucion-renovable-no-renovable.html.twig
#    * html--apidatos--datos--generacion.html.twig
#    * html--apidatos--datos.html.twig
#    * html--apidatos.html.twig
#    x html.html.twig
# -->
# <!-- BEGIN OUTPUT from 'themes/custom/newco/templates/layout/html.html.twig' -->
#
# <!DOCTYPE html>
# <html lang="es" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# " class="h-100">
#   <head>
#     <meta charset="utf-8" />
# ...
